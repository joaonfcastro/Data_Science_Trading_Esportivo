# %% [markdown]
# <a href="https://colab.research.google.com/github/joaonfcastro/Data_Science_Trading_Esportivo/blob/main/Data_Prep_Trading_Esportivo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Data Prep Trading Esportivo**
# ![data-preparation-diagram_0.svg](data:image/svg+xml;base64,...)

# %% [markdown]
# #### **Loading Packages**

# %%
#Packages Prepare and Exploratory Data
import pandas as pd
import numpy as np
import seaborn as sns
from google.colab import files
import warnings
from datetime import datetime
import plotly.express as px
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', 300)
pd.set_option('display.max_rows', 300)
warnings.filterwarnings('ignore', category=FutureWarning)

# %% [markdown]
# #### **Loading Datasets**

# %% [markdown]
# ###### Premier League

# %%
#Load datasets
df_1 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/E0.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_2 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/E0.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_3 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/E0.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_4 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/E0.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_5 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/E0.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_6 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/E0.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_7 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/E0.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_8 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/E0.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_9 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/E0.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_10 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/E0.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])

#Insert Column League
df_1['League'] = 'Premier League'
df_2['League'] = 'Premier League'
df_3['League'] = 'Premier League'
df_4['League'] = 'Premier League'
df_5['League'] = 'Premier League'
df_6['League'] = 'Premier League'
df_7['League'] = 'Premier League'
df_8['League'] = 'Premier League'
df_9['League'] = 'Premier League'
df_10['League'] = 'Premier League'

#Insert Column Season
df_1['Season'] = '23-24'
df_2['Season'] = '22-23'
df_3['Season'] = '21-22'
df_4['Season'] = '20-21'
df_5['Season'] = '19-20'
df_6['Season'] = '18-19'
df_7['Season'] = '17-18'
df_8['Season'] = '16-17'
df_9['Season'] = '15-16'
df_10['Season'] = '14-15'

# %%
df_11
# Out:
#           Date       HomeTeam       AwayTeam  FTHG  FTAG FTR  HST  AST  HF  \
# 0   18/08/2023  Werder Bremen  Bayern Munich     0     4   A    1   10  16
# 1   19/08/2023       Augsburg     M'gladbach     4     4   D    8    6   9
# 2   19/08/2023     Hoffenheim       Freiburg     1     2   A    5    8   9
# 3   19/08/2023     Leverkusen     RB Leipzig     3     2   H    7    6  13
# 4   19/08/2023      Stuttgart         Bochum     5     0   H    9    1   5
# 5   19/08/2023      Wolfsburg     Heidenheim     2     0   H    8    1  10
# 6   19/08/2023       Dortmund        FC Koln     1     0   H    2    4  13
# 7   20/08/2023   Union Berlin          Mainz     4     1   H    7    3  15
# 8   20/08/2023  Ein Frankfurt      Darmstadt     1     0   H    4    2   9
# 9   25/08/2023     RB Leipzig      Stuttgart     5     1   H   11    3  12
# 10  26/08/2023         Bochum       Dortmund     1     1   D    6    3  21
# ...

# %% [markdown]
# ###### Budesliga

# %%
#Load datasets
df_11 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/D1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_12 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/D1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_13 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/D1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_14 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/D1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_15 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/D1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_16 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/D1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_17 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/D1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_18 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/D1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_19 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/D1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_20 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/D1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])

#Insert Column League
df_11['League'] = 'Budesliga'
df_12['League'] = 'Budesliga'
df_13['League'] = 'Budesliga'
df_14['League'] = 'Budesliga'
df_15['League'] = 'Budesliga'
df_16['League'] = 'Budesliga'
df_17['League'] = 'Budesliga'
df_18['League'] = 'Budesliga'
df_19['League'] = 'Budesliga'
df_20['League'] = 'Budesliga'

#Insert Column Season
df_11['Season'] = '23-24'
df_12['Season'] = '22-23'
df_13['Season'] = '21-22'
df_14['Season'] = '20-21'
df_15['Season'] = '19-20'
df_16['Season'] = '18-19'
df_17['Season'] = '17-18'
df_18['Season'] = '16-17'
df_19['Season'] = '15-16'
df_20['Season'] = '14-15'

# %% [markdown]
# ###### La Liga

# %%
#Load datasets
df_21 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/SP1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_22 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/SP1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_23 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/SP1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_24 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/SP1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_25 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/SP1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_26 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/SP1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_27 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/SP1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_28 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/SP1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_29 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/SP1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_30 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/SP1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])

#Insert Column League
df_21['League'] = 'LaLiga'
df_22['League'] = 'LaLiga'
df_23['League'] = 'LaLiga'
df_24['League'] = 'LaLiga'
df_25['League'] = 'LaLiga'
df_26['League'] = 'LaLiga'
df_27['League'] = 'LaLiga'
df_28['League'] = 'LaLiga'
df_29['League'] = 'LaLiga'
df_30['League'] = 'LaLiga'

#Insert Column Season
df_21['Season'] = '23-24'
df_22['Season'] = '22-23'
df_23['Season'] = '21-22'
df_24['Season'] = '20-21'
df_25['Season'] = '19-20'
df_26['Season'] = '18-19'
df_27['Season'] = '17-18'
df_28['Season'] = '16-17'
df_29['Season'] = '15-16'
df_30['Season'] = '14-15'

# %% [markdown]
# ###### Calcio

# %%
#Load datasets
df_31 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/I1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_32 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/I1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_33 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/I1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_34 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/I1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_35 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/I1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_36 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/I1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_37 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/I1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_38 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/I1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_39 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/I1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_40 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/I1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])

#Insert Column League
df_31['League'] = 'Calcio'
df_32['League'] = 'Calcio'
df_33['League'] = 'Calcio'
df_34['League'] = 'Calcio'
df_35['League'] = 'Calcio'
df_36['League'] = 'Calcio'
df_37['League'] = 'Calcio'
df_38['League'] = 'Calcio'
df_39['League'] = 'Calcio'
df_40['League'] = 'Calcio'

#Insert Column Season
df_31['Season'] = '23-24'
df_32['Season'] = '22-23'
df_33['Season'] = '21-22'
df_34['Season'] = '20-21'
df_35['Season'] = '19-20'
df_36['Season'] = '18-19'
df_37['Season'] = '17-18'
df_38['Season'] = '16-17'
df_39['Season'] = '15-16'
df_40['Season'] = '14-15'

# %% [markdown]
# ###### Ligue 1

# %%
#Load datasets
df_41 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/F1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_42 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/F1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_43 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/F1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_44 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/F1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_45 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/F1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_46 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/F1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_47 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/F1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_48 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1617/F1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_49 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1516/F1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_50 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1415/F1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])

#Insert Column League
df_41['League'] = 'Ligue 1'
df_42['League'] = 'Ligue 1'
df_43['League'] = 'Ligue 1'
df_44['League'] = 'Ligue 1'
df_45['League'] = 'Ligue 1'
df_46['League'] = 'Ligue 1'
df_47['League'] = 'Ligue 1'
df_48['League'] = 'Ligue 1'
df_49['League'] = 'Ligue 1'
df_50['League'] = 'Ligue 1'

#Insert Column Season
df_41['Season'] = '23-24'
df_42['Season'] = '22-23'
df_43['Season'] = '21-22'
df_44['Season'] = '20-21'
df_45['Season'] = '19-20'
df_46['Season'] = '18-19'
df_47['Season'] = '17-18'
df_48['Season'] = '16-17'
df_49['Season'] = '15-16'
df_50['Season'] = '14-15'

# %% [markdown]
# ###### Eredivisie

# %%
#Load datasets
df_51 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/N1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_52 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/N1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_53 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/N1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_54 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/N1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_55 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/N1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_56 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/N1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_57 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/N1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])

#Insert Column League
df_51['League'] = 'Eredivisie'
df_52['League'] = 'Eredivisie'
df_53['League'] = 'Eredivisie'
df_54['League'] = 'Eredivisie'
df_55['League'] = 'Eredivisie'
df_56['League'] = 'Eredivisie'
df_57['League'] = 'Eredivisie'

#Insert Column Season
df_51['Season'] = '23-24'
df_52['Season'] = '22-23'
df_53['Season'] = '21-22'
df_54['Season'] = '20-21'
df_55['Season'] = '19-20'
df_56['Season'] = '18-19'
df_57['Season'] = '17-18'

# %% [markdown]
# ###### Liga Portugal

# %%
#Load datasets
df_61 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2324/P1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_62 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2223/P1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_63 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2122/P1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_64 = pd.read_csv("https://www.football-data.co.uk/mmz4281/2021/P1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_65 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1920/P1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_66 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1819/P1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])
df_67 = pd.read_csv("https://www.football-data.co.uk/mmz4281/1718/P1.csv", usecols = ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HST', 'AST', 'HC', 'AC', 'HF', 'AF', 'HY', 'AY', 'HR', 'AR', 'B365H','B365D', 'B365A'])

#Insert Column League
df_61['League'] = 'Liga Portugal'
df_62['League'] = 'Liga Portugal'
df_63['League'] = 'Liga Portugal'
df_64['League'] = 'Liga Portugal'
df_65['League'] = 'Liga Portugal'
df_66['League'] = 'Liga Portugal'
df_67['League'] = 'Liga Portugal'

#Insert Column Season
df_61['Season'] = '23-24'
df_62['Season'] = '22-23'
df_63['Season'] = '21-22'
df_64['Season'] = '20-21'
df_65['Season'] = '19-20'
df_66['Season'] = '18-19'
df_67['Season'] = '17-18'

# %% [markdown]
# #### **Concat Datasets**

# %%
#Concat datasets
df =  [df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,df_10,
       df_11,df_12,df_13,df_14,df_15,df_16,df_17,df_18,df_19,df_20,
       df_21,df_22,df_23,df_24,df_25,df_26,df_27,df_28,df_29,df_30,
       df_31,df_32,df_33,df_34,df_35,df_36,df_37,df_38,df_39,df_40,
       df_41,df_42,df_43,df_44,df_45,df_46,df_47,df_48,df_49,df_50,
       df_51,df_52,df_53,df_54,df_55,df_56,df_57,
       df_61,df_62,df_63,df_64,df_65,df_66,df_67]
df = pd.concat(df)
df.head()
# Out:
#          Date     HomeTeam       AwayTeam  FTHG  FTAG FTR   HST  AST    HF  \
# 0  11/08/2023      Burnley       Man City   0.0   3.0   A   1.0  8.0  11.0
# 1  12/08/2023      Arsenal  Nott'm Forest   2.0   1.0   H   7.0  2.0  12.0
# 2  12/08/2023  Bournemouth       West Ham   1.0   1.0   D   5.0  3.0   9.0
# 3  12/08/2023     Brighton          Luton   4.0   1.0   H  12.0  3.0  11.0
# 4  12/08/2023      Everton         Fulham   0.0   1.0   A   9.0  2.0  12.0
#
#      AF    HC   AC   HY   AY   HR   AR  B365H  B365D  B365A          League  \
# 0   8.0   6.0  5.0  0.0  0.0  1.0  0.0   8.00    5.5   1.33  Premier League
# 1  12.0   8.0  3.0  2.0  2.0  0.0  0.0   1.18    7.0  15.00  Premier League
# 2  14.0  10.0  4.0  1.0  4.0  0.0  0.0   2.70    3.4   2.55  Premier League
# 3  12.0   6.0  7.0  2.0  2.0  0.0  0.0   1.33    5.5   9.00  Premier League
# 4   6.0  10.0  4.0  0.0  2.0  0.0  0.0   2.20    3.4   3.30  Premier League
#
#   Season
# 0  23-24
# 1  23-24
# 2  23-24
# 3  23-24
# ...

# %% [markdown]
# #### **Adjust names columns and position**

# %%
#Adjust Name Columns
df =  df.rename(columns={'HomeTeam':'Home',
                   'AwayTeam':'Away',
                   'FTHG':"HomeGoals",
                   'FTAG':"AwayGoals",
                   'FTR':'Result',
                   'HST':'HomeShootsTarget',
                   'AST':'AwayShootsTarget',
                   'HC':'HomeCorners',
                   'AC':'AwayCorners',
                   'HF':'HomeFouls',
                   'AF':'AwayFouls',
                   'HY':'HomeYellow',
                   'AY':'AwayYellow',
                   'HR':'HomeRed',
                   'AR':'AwayRed',
                   'B365H':'HomeOdds',
                   'B365D':'DrawOdds',
                   'B365A':'AwayOdds'})
df.head()
# Out:
#          Date         Home           Away  HomeGoals  AwayGoals Result  \
# 0  11/08/2023      Burnley       Man City        0.0        3.0      A
# 1  12/08/2023      Arsenal  Nott'm Forest        2.0        1.0      H
# 2  12/08/2023  Bournemouth       West Ham        1.0        1.0      D
# 3  12/08/2023     Brighton          Luton        4.0        1.0      H
# 4  12/08/2023      Everton         Fulham        0.0        1.0      A
#
#    HomeShootsTarget  AwayShootsTarget  HomeFouls  AwayFouls  HomeCorners  \
# 0               1.0               8.0       11.0        8.0          6.0
# 1               7.0               2.0       12.0       12.0          8.0
# 2               5.0               3.0        9.0       14.0         10.0
# 3              12.0               3.0       11.0       12.0          6.0
# 4               9.0               2.0       12.0        6.0         10.0
#
#    AwayCorners  HomeYellow  AwayYellow  HomeRed  AwayRed  HomeOdds  DrawOdds  \
# ...

# %%
#Alter position columns
df = df[['League', 'Season', 'Date', 'Home', 'Away', 'HomeGoals', 'AwayGoals', 'Result',
       'HomeShootsTarget', 'AwayShootsTarget', 'HomeFouls', 'AwayFouls',
       'HomeCorners', 'AwayCorners', 'HomeYellow', 'AwayYellow', 'HomeRed',
       'AwayRed', 'HomeOdds', 'DrawOdds', 'AwayOdds']]
df.head()
# Out:
#            League Season        Date         Home           Away  HomeGoals  \
# 0  Premier League  23-24  11/08/2023      Burnley       Man City        0.0
# 1  Premier League  23-24  12/08/2023      Arsenal  Nott'm Forest        2.0
# 2  Premier League  23-24  12/08/2023  Bournemouth       West Ham        1.0
# 3  Premier League  23-24  12/08/2023     Brighton          Luton        4.0
# 4  Premier League  23-24  12/08/2023      Everton         Fulham        0.0
#
#    AwayGoals Result  HomeShootsTarget  AwayShootsTarget  HomeFouls  AwayFouls  \
# 0        3.0      A               1.0               8.0       11.0        8.0
# 1        1.0      H               7.0               2.0       12.0       12.0
# 2        1.0      D               5.0               3.0        9.0       14.0
# 3        1.0      H              12.0               3.0       11.0       12.0
# 4        1.0      A               9.0               2.0       12.0        6.0
#
# ...

# %% [markdown]
# #### **Exploratory and Adjusts Data**

# %%
#Info dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20173 entries, 0 to 305
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   League            20173 non-null  object
#  1   Season            20173 non-null  object
#  2   Date              20169 non-null  object
#  3   Home              20169 non-null  object
#  4   Away              20169 non-null  object
#  5   HomeGoals         20169 non-null  float64
#  6   AwayGoals         20169 non-null  float64
#  7   Result            20169 non-null  object
#  8   HomeShootsTarget  20168 non-null  float64
#  9   AwayShootsTarget  20168 non-null  float64
#  10  HomeFouls         20168 non-null  float64
#  11  AwayFouls         20168 non-null  float64
#  12  HomeCorners       20168 non-null  float64
#  13  AwayCorners       20168 non-null  float64
#  14  HomeYellow        20167 non-null  float64
#  15  AwayYellow        20168 non-null  float64
# ...

# %%
#Shape dataset
df.shape
# Out:
# (20173, 21)

# %%
#Transform Datetime
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

# %%
df.head()
# Out:
#           Date    HomeTeam     AwayTeam  FTHG  FTAG FTR  HST  AST    HF    AF  \
# 149 2022-12-31  Villarreal     Valencia   2.0   1.0   H  8.0  4.0  12.0  16.0
# 160 2022-12-31      Fulham  Southampton   2.0   1.0   H  2.0  3.0   8.0  13.0
# 158 2022-12-31      Wolves   Man United   0.0   1.0   A  3.0  6.0  11.0  11.0
# 148 2022-12-31    Sociedad      Osasuna   2.0   0.0   H  2.0  3.0  10.0  15.0
# 147 2022-12-31   Barcelona      Espanol   1.0   1.0   D  6.0  1.0  11.0  15.0
#
#        HC   AC   HY   AY   HR   AR  B365H  B365D  B365A          League Season
# 149   5.0  2.0  1.0  3.0  0.0  0.0   1.95    3.4   4.20          LaLiga  22-23
# 160   4.0  4.0  0.0  1.0  0.0  0.0   1.95    3.6   3.75  Premier League  22-23
# 158   7.0  5.0  1.0  3.0  0.0  0.0   4.00    3.6   1.91  Premier League  22-23
# 148   3.0  2.0  1.0  1.0  0.0  0.0   1.85    3.3   4.75          LaLiga  22-23
# 147  10.0  2.0  6.0  7.0  1.0  1.0   1.25    6.5  10.00          LaLiga  22-23

# %%
#Check Missing Values
df.isnull().sum()
# Out:
# League               0
# Season               0
# Date                 4
# Home                 4
# Away                 4
# HomeGoals            4
# AwayGoals            4
# Result               4
# HomeShootsTarget     5
# AwayShootsTarget     5
# HomeFouls            5
# AwayFouls            5
# HomeCorners          5
# AwayCorners          5
# HomeYellow           6
# AwayYellow           5
# HomeRed              5
# AwayRed              5
# HomeOdds            13
# DrawOdds            13
# AwayOdds            13
# dtype: int64

# %%
#Excluded Missing
df = df.dropna()

# %%
#Check Missing Values
df.isnull().sum()
# Out:
# League              0
# Season              0
# Date                0
# Home                0
# Away                0
# HomeGoals           0
# AwayGoals           0
# Result              0
# HomeShootsTarget    0
# AwayShootsTarget    0
# HomeFouls           0
# AwayFouls           0
# HomeCorners         0
# AwayCorners         0
# HomeYellow          0
# AwayYellow          0
# HomeRed             0
# AwayRed             0
# HomeOdds            0
# DrawOdds            0
# AwayOdds            0
# dtype: int64

# %%
#Shape dataset
df.shape
# Out:
# (20158, 21)

# %%
#Sort Date
df = df.sort_values(by='Date', ascending=False)
df.head()
# Out:
#             League Season       Date     Home         Away  HomeGoals  \
# 29          Calcio  23-24 2023-09-03    Lecce  Salernitana        2.0
# 38          LaLiga  23-24 2023-09-03  Osasuna    Barcelona        1.0
# 32   Liga Portugal  23-24 2023-09-03  Estoril     Boavista        1.0
# 31   Liga Portugal  23-24 2023-09-03   Chaves   Moreirense        1.0
# 38  Premier League  23-24 2023-09-03  Arsenal   Man United        3.0
#
#     AwayGoals Result  HomeShootsTarget  AwayShootsTarget  HomeFouls  \
# 29        0.0      H               6.0               4.0       17.0
# 38        2.0      A               3.0               4.0        6.0
# 32        2.0      A               4.0               8.0       21.0
# 31        2.0      A               3.0               2.0       14.0
# 38        1.0      H               5.0               2.0        8.0
#
#     AwayFouls  HomeCorners  AwayCorners  HomeYellow  AwayYellow  HomeRed  \
# ...

# %% [markdown]
# #### **Create Index Match**

# %%
#Create column match and index
df['Match'] = range(1, len(df) + 1)
df = df.set_index('Match')
df = df.reset_index()
df.head()
# Out:
#    Match          League Season       Date     Home         Away  HomeGoals  \
# 0      1          Calcio  23-24 2023-09-03    Lecce  Salernitana        2.0
# 1      2          LaLiga  23-24 2023-09-03  Osasuna    Barcelona        1.0
# 2      3   Liga Portugal  23-24 2023-09-03  Estoril     Boavista        1.0
# 3      4   Liga Portugal  23-24 2023-09-03   Chaves   Moreirense        1.0
# 4      5  Premier League  23-24 2023-09-03  Arsenal   Man United        3.0
#
#    AwayGoals Result  HomeShootsTarget  AwayShootsTarget  HomeFouls  AwayFouls  \
# 0        0.0      H               6.0               4.0       17.0       15.0
# 1        2.0      A               3.0               4.0        6.0       16.0
# 2        2.0      A               4.0               8.0       21.0       12.0
# 3        2.0      A               3.0               2.0       14.0       21.0
# 4        1.0      H               5.0               2.0        8.0        7.0
#
# ...

# %% [markdown]
# #### **Export Data**

# %%
#Export file summary stats
df.to_excel('df_football_hist_10_years.xlsx')
files.download('df_football_hist_10_years.xlsx')
